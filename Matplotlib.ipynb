# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [2, 4, 6, 8, 10]
y = [8, 16, 22, 26, 42]

# %%
plt.plot(x, y, 'g--*')
plt.show()

# %%
plt.plot(x, y, 'y--.')
plt.show()

# %%
plt.plot(x, y, 'r--*')
plt.show()

# %%
plt.plot(x, y,color = 'orange')
plt.title("Premier visualisation")
plt.show()

# %%
X = [1, 6, 8, 10, 18, 19, 22, 28, 30 ]
Y = [12, 100, 58, 17, 60, 2, 80, 3, 7]

# %%
plt.plot(X, Y, "b-*")
plt.title("Visualition de Younousse et Bakar")
plt.grid()
plt.xlabel('x - axe des abscisses ')
plt.ylabel('y - axe des ordonnées')
plt.legend(["blue"])
plt.savefig('Documents/PlotgeneratedusingMatplotlib.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5440\2113241518.py in <module>
#       5 plt.ylabel('y - axe des ordonnées')
#       6 plt.legend(["blue"])
# ----> 7 plt.savefig('Documents/PlotgeneratedusingMatplotlib.png')
#       8 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3045
# -> 3046             self.canvas.print_figure(fname, **kwargs)
#    3047
# ...

# %%
import matplotlib.pyplot as plt
nom=['Modou','Astou','Khady','Fatou','Mbaye']
Age=[15,35,40,25,19]

plt.bar(nom,Age,color=['red','blue','yellow','orange','Cyan'])
#ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

plt.show()

# %%
nom=['Modou','Astou','Khady','Fatou','Mbaye','Mamadou','Ousmane','BIAYE','Rama','Ibrahima','Seyni','Bourama','Khalil','Alpha']
Age=[15,35,40,25,19,21,32,19,18,16,25,29,21,23]
plt.figure(figsize=(20,20),dpi=300) # Taille des bandes
colors=['red','blue','yellow','orange','Cyan','Olive','teal','tan','magenta','violet','olive','coral','purple','orange']
bars=plt.bar(nom,Age,color=colors)
#plt.bar(nom,Age,color=['red','blue','yellow','orange','Cyan','Olive','teal','tan','magenta','violet','olive','coral','purple','indigo'])
patterns=['///','*','o','.','//','..','/','**','oo','+','++','/////', '|||', '+*+']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
nom=['Modou','Astou','Khady','Fatou','Mbaye']
Age=[15,35,40,25,19]
plt.pie(Age, labels=Age, autopct='%.2f%%')
plt.legend(bbox_to_anchor=(1.05, 1.0, 0.3, 0.2), loc='center')
plt.show()

# %%
Categories = ["Echantillon 1","Echantillon 2","Echantillon 3"] # 3 échantillons

Sous_categories = ['Qualité', 'Environnement', 'Social','Bien-être'] # comparés selon 4 critères

# Valeurs pour chaque catégories

y1 = [1, 2, 5, 2] ; y2 = [1, 6, 4, 2] ; y3 = [1, 6, 4, 2]

from math import * 

nb_categories = len(Categories)

largeur_barre = floor(1*10/nb_categories)/10

x1 = range(len(y1))

x2 = [i + largeur_barre for i in x1]

x3 = [i + 2*largeur_barre for i in x1]

plt.bar(x1, y1, width = largeur_barre, color = 'red',

           edgecolor = 'black', linewidth = 2)

plt.bar(x2, y2, width = largeur_barre, color = 'blue',

           edgecolor = 'black', linewidth = 2)

plt.bar(x3, y3, width = largeur_barre, color = 'green',

           edgecolor = 'black', linewidth = 2)

plt.xticks([r + largeur_barre / nb_categories for r in range(len(y1))],

              Sous_categories)

plt.legend(Categories,loc=2)

plt.show()
