# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temperature = [33, 19, 15, 39, 11, -5, 9]
jours = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

# %%
temps = pd.Series(temperature, index=jours)

# %%
temps.describe()
# Out:
# count     7.000000
# mean     17.285714
# std      14.896468
# min      -5.000000
# 25%      10.000000
# 50%      15.000000
# 75%      26.000000
# max      39.000000
# dtype: float64

# %%
temps.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, Lundi to Dimanche
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      int64
# dtypes: int64(1)
# memory usage: 112.0+ bytes

# %%
temps.Dimanche
# Out:
# 9

# %%
my_dict = {'Lundi':33, 'Mardi':19, 'Mercredi':15, 'Jeudi':34, 'Vendredi':23, 'Samedi':32, 'Dimanche':26}

# %%
series_from_dict = pd.Series(my_dict)
series_from_dict.iloc[0:1][0:]
# Out:
# Lundi    33
# dtype: int64

# %%
taille = pd.DataFrame(
[1, 2, 3], ["chien", "chat", "mouse"])
taille
# Out:
#        0
# chien  1
# chat   2
# mouse  3

# %%
np.random.seed(0)
x = pd.DataFrame(
{
    'prix' : np.random.uniform(size=5),
    'quantite' : [i+1 for i in range(5)]},
    index = ['yaourt', 'pates', 'riz', 'tomates', 'gateaux']
)
x
# Out:
#              prix  quantite
# yaourt   0.548814         1
# pates    0.715189         2
# riz      0.602763         3
# tomates  0.544883         4
# gateaux  0.423655         5

# %%
y = pd.DataFrame(
    {
        'prix' : [np.nan, 0, 1, 2, 3],
        'quantite' : [i+1 for i in range(5)]
    },
    index = ['tomates', 'yaourt', 'gateaux', 'pates', 'riz']
)
y
# Out:
#          prix  quantite
# tomates   NaN         1
# yaourt    0.0         2
# gateaux   1.0         3
# pates     2.0         4
# riz       3.0         5

# %%
df = pd.read_csv("https://koumoul.com/s/data-fair/api/v1/datasets/igt-pouvoir-de-rechauffement-global/convert", sep=",")
df
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577909
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %%
data = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv', sep=",")

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.describe().to_excel('rama.xlsx')

# %%
data.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
data.Age.head()
# Out:
# 0    41
# 1    49
# 2    37
# 3    33
# 4    27
# Name: Age, dtype: int64

# %%
data.PercentSalaryHike.head()
# Out:
# 0    11
# 1    23
# 2    15
# 3    11
# 4    12
# Name: PercentSalaryHike, dtype: int64

# %%
data.YearsAtCompany.head()
# Out:
# 0     6
# 1    10
# 2     0
# 3     8
# 4     2
# Name: YearsAtCompany, dtype: int64

# %%
data.YearsInCurrentRole.head()
# Out:
# 0    4
# 1    7
# 2    0
# 3    7
# 4    2
# Name: YearsInCurrentRole, dtype: int64

# %%
data[['Age', 'YearsAtCompany']]
# Out:
#       Age  YearsAtCompany
# 0      41               6
# 1      49              10
# 2      37               0
# 3      33               8
# 4      27               2
# ...   ...             ...
# 1465   36               5
# 1466   39               7
# 1467   27               6
# 1468   49               9
# 1469   34               4
#
# [1470 rows x 2 columns]

# %%
plt.bar(data.YearsAtCompany.head(5), data.Age.head(5))
plt.show()

# %%
data.Bak = 5

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data['AgeInMonths'] = 12 * data['Age']

# %%
del data['AgeInMonths']

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
selected_EmployeeNumbers = [15, 94, 337, 1120]

# %%
data['YearsAtCompany'].loc[selected_EmployeeNumbers]
# Out:
# 15      10
# 94      11
# 337      3
# 1120     3
# Name: YearsAtCompany, dtype: int64

# %%
data.loc[94, 'YearsAtCompany']
data['Attrition'].count()
# Out:
# 1470

# %%
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
percentage = ( data['Attrition'].value_counts()['Yes'] * 100 ) / (data.Attrition.count())
print(f"Le pourcentage d'attrition est de {percentage} % ")
# Out:
# Le pourcentage d'attrition est de 16.122448979591837 %

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.HourlyRate.mean()
# Out:
# 65.89115646258503

# %%
h =
